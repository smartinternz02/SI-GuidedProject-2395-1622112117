# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("E:\Geethanjaliexternship\CO2-Emission-of-Cars-main\Dataset\Sample.csv")

# %%
dataset
# Out:
#      MODEL        MAKE                      MODEL.1             VEHICLE CLASS  \
# 0     2001       ACURA                        1.7EL                   COMPACT
# 1     2001       ACURA                        1.7EL                   COMPACT
# 2     2001       ACURA                        3.2CL                   COMPACT
# 3     2001       ACURA                        3.2TL                  MID-SIZE
# 4     2001       ACURA                        3.5RL                  MID-SIZE
# 5     2001       ACURA                      INTEGRA                SUBCOMPACT
# 6     2001       ACURA                      INTEGRA                SUBCOMPACT
# 7     2001       ACURA                 INTEGRA GS-R                SUBCOMPACT
# 8     2001       ACURA                          MDX                       SUV
# 9     2001       ACURA                          NSX                TWO-SEATER
# 10    2001       ACURA                          NSX                TWO-SEATER
# ...

# %%
dataset.head()
# Out:
#    MODEL   MAKE MODEL.1 VEHICLE CLASS  ENGINE_SIZE  CYLINDERS TRANSMISSION  \
# 0   2001  ACURA   1.7EL       COMPACT          1.7          4           A4
# 1   2001  ACURA   1.7EL       COMPACT          1.7          4           M5
# 2   2001  ACURA   3.2CL       COMPACT          3.2          6          AS5
# 3   2001  ACURA   3.2TL      MID-SIZE          3.2          6          AS5
# 4   2001  ACURA   3.5RL      MID-SIZE          3.5          6           A4
#
#   FUEL  FUEL_CONSUMPTION*  Unnamed: 9  Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# 0    X                9.3         7.2          8.3           34            191
# 1    X                8.9         7.4          8.3           34            191
# 2    Z               13.7         8.8         11.5           25            265
# 3    Z               13.8         8.8         11.6           24            267
# 4    Z               15.0        10.9         13.1           22            301

# %%
dataset["MAKE"].mode()[0]
# Out:
# 'FORD'

# %%
dataset["MODEL.1"].mode()[0]
# Out:
# 'RAM 1500'

# %%
dataset["VEHICLE CLASS"].mode()[0]
# Out:
# 'COMPACT'

# %%
dataset["TRANSMISSION"].mode()[0]
# Out:
# 'A4'

# %%
dataset['FUEL'].mode()[0]
# Out:
# 'X'

# %%
dataset['MAKE'].unique()
# Out:
# array(['ACURA', 'AUDI', 'BMW', 'BUICK', 'CADILLAC', 'CHEVROLET',
#        'CHRYSLER', 'DAEWOO', 'DODGE', 'FORD', 'GMC', 'HONDA', 'HYUNDAI',
#        'INFINITI', 'ISUZU', 'JAGUAR', 'JEEP', 'KIA', 'LEXUS', 'LINCOLN',
#        'MAZDA', 'MERCEDES-BENZ', 'NISSAN', 'OLDSMOBILE', 'PLYMOUTH',
#        'PONTIAC', 'PORSCHE', 'SAAB', 'SATURN', 'SUBARU', 'SUZUKI',
#        'TOYOTA', 'VOLKSWAGEN', 'VOLVO'], dtype=object)

# %%
dataset['MODEL.1'].unique()
# Out:
# array(['1.7EL', '3.2CL', '3.2TL', '3.5RL', 'INTEGRA', 'INTEGRA GS-R',
#        'MDX', 'NSX', 'A4', 'A4 QUATTRO', 'A6', 'A6 AVANT QUATTRO WAGON',
#        'A6 QUATTRO', 'A8 L', 'A8 QUATTRO', 'ALLROAD', 'S4 QUATTRO',
#        'S8 QUATTRO #', 'TT COUPE QUATTRO', 'TT COUPE QUATTRO #',
#        'TT ROADSTER', 'TT ROADSTER QUATTRO #', '320i', '325Ci',
#        '325Ci CONVERTIBLE', '325i', '325xi', '330Ci', '330Ci CONVERTIBLE',
#        '330i', '330xi', '525i', '525i SPORT WAGON', '530i', '540i',
#        '540i SPORT WAGON', '740i', '740iL', '750iL', 'M COUPE',
#        'M ROADSTER', 'M3', 'M3 CONVERTIBLE', 'M5', 'X5', 'Z3', 'Z8',
#        'CENTURY', 'LESABRE', 'PARK AVENUE', 'PARK AVENUE #', 'REGAL',
#        'REGAL #', 'CATERA', 'DEVILLE', 'ELDORADO', 'SEVILLE',
#        'ASTRO CARGO', 'ASTRO CARGO AWD', 'ASTRO PASSENGER',
#        'ASTRO PASSENGER AWD', 'BLAZER', 'BLAZER 4X4', 'C1500 SILVERADO',
#        'C1500 SUBURBAN', 'C1500 TAHOE', 'CAMARO', 'CAVALIER',
# ...

# %%
dataset["VEHICLE CLASS"].unique()
# Out:
# array(['COMPACT', 'MID-SIZE', 'SUBCOMPACT', 'SUV', 'TWO-SEATER',
#        'STATION WAGON - MID-SIZE', 'FULL-SIZE', 'MINICOMPACT',
#        'STATION WAGON - SMALL', 'VAN - CARGO', 'VAN - PASSENGER',
#        'PICKUP TRUCK - STANDARD', 'PICKUP TRUCK - SMALL', 'MINIVAN'],
#       dtype=object)

# %%
dataset["MODEL.1"]
# Out:
# 0                            1.7EL
# 1                            1.7EL
# 2                            3.2CL
# 3                            3.2TL
# 4                            3.5RL
# 5                          INTEGRA
# 6                          INTEGRA
# 7                     INTEGRA GS-R
# 8                              MDX
# 9                              NSX
# 10                             NSX
# 11                              A4
# 12                              A4
# 13                              A4
# 14                      A4 QUATTRO
# 15                      A4 QUATTRO
# 16                      A4 QUATTRO
# 17                      A4 QUATTRO
# 18                              A6
# 19          A6 AVANT QUATTRO WAGON
# 20                      A6 QUATTRO
# 21                      A6 QUATTRO
# 22                      A6 QUATTRO
# 23                      A6 QUATTRO
# 24                            A8 L
# 25                      A8 QUATTRO
# 26                         ALLROAD
# ...

# %%
dataset['TRANSMISSION'].unique()
# Out:
# array(['A4', 'M5', 'AS5', 'A5', 'AS4', 'M6', 'A3', 'AV'], dtype=object)

# %%
dataset['FUEL'].unique()
# Out:
# array(['X', 'Z', 'E', 'N', 'D'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset["MAKE"] = le.fit_transform(dataset["MAKE"])
dataset["VEHICLE CLASS"] = le.fit_transform(dataset["VEHICLE CLASS"])
dataset["TRANSMISSION"] = le.fit_transform(dataset["TRANSMISSION"])
dataset["FUEL"] = le.fit_transform(dataset["FUEL"])

# %%
dataset.head()
# Out:
#    MODEL  MAKE MODEL.1  VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  TRANSMISSION  \
# 0   2001     0   1.7EL              0          1.7          4             1
# 1   2001     0   1.7EL              0          1.7          4             6
# 2   2001     0   3.2CL              0          3.2          6             4
# 3   2001     0   3.2TL              2          3.2          6             4
# 4   2001     0   3.5RL              2          3.5          6             1
#
#    FUEL  FUEL_CONSUMPTION*  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0     3                9.3         7.2          8.3           34
# 1     3                8.9         7.4          8.3           34
# 2     4               13.7         8.8         11.5           25
# 3     4               13.8         8.8         11.6           24
# 4     4               15.0        10.9         13.1           22
#
#    CO2_EMISSIONS
# 0            191
# 1            191
# 2            265
# 3            267
# 4            301

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 679 entries, 0 to 678
# Data columns (total 13 columns):
# MODEL                679 non-null int64
# MAKE                 679 non-null int32
# MODEL.1              679 non-null object
# VEHICLE CLASS        679 non-null int32
# ENGINE_SIZE          679 non-null float64
# CYLINDERS            679 non-null int64
# TRANSMISSION         679 non-null int32
# FUEL                 679 non-null int32
# FUEL_CONSUMPTION*    679 non-null float64
# Unnamed: 9           679 non-null float64
# Unnamed: 10          679 non-null float64
# Unnamed: 11          679 non-null int64
# CO2_EMISSIONS        679 non-null int64
# dtypes: float64(4), int32(4), int64(4), object(1)
# memory usage: 58.4+ KB

# %%
dataset.rename({'FUEL_CONSUMPTION':'FUEL_CONSUMPTION_CITY','Unnamed:9':'FUEL_CONSUMPTION_HIGHWAY','Unnamed: 10':'FUEL_CONSUMPTION_COMB(L/100 KM)','Unnamed:11':'FUEL_CONSUMPTION_COMB(MPG)'},axis = 1, inplace = True)
dataset
# Out:
#      MODEL  MAKE                      MODEL.1  VEHICLE CLASS  ENGINE_SIZE  \
# 0     2001     0                        1.7EL              0          1.7
# 1     2001     0                        1.7EL              0          1.7
# 2     2001     0                        3.2CL              0          3.2
# 3     2001     0                        3.2TL              2          3.2
# 4     2001     0                        3.5RL              2          3.5
# 5     2001     0                      INTEGRA              9          1.8
# 6     2001     0                      INTEGRA              9          1.8
# 7     2001     0                 INTEGRA GS-R              9          1.8
# 8     2001     0                          MDX             10          3.5
# 9     2001     0                          NSX             11          3.0
# 10    2001     0                          NSX             11          3.2
# 11    2001     1                           A4              0          1.8
# ...

# %%
dataset.describe()
# Out:
#         MODEL        MAKE  VEHICLE CLASS  ENGINE_SIZE   CYLINDERS  \
# count   679.0  679.000000     679.000000   679.000000  679.000000
# mean   2001.0   15.275405       5.421208     3.252577    5.798233
# std       0.0   10.498455       4.203092     1.203751    1.531073
# min    2001.0    0.000000       0.000000     1.000000    3.000000
# 25%    2001.0    6.000000       1.000000     2.200000    4.000000
# 50%    2001.0   11.000000       6.000000     3.000000    6.000000
# 75%    2001.0   25.000000       9.500000     4.200000    6.000000
# max    2001.0   33.000000      13.000000     8.000000   12.000000
#
#        TRANSMISSION        FUEL  FUEL_CONSUMPTION*  Unnamed: 9  \
# count    679.000000  679.000000         679.000000  679.000000
# mean       2.946981    3.284242          14.591900   10.613844
# std        2.314534    0.597612           3.025654    2.357724
# min        0.000000    0.000000           4.900000    4.000000
# ...

# %%
dataset.head()
# Out:
#    MODEL  MAKE MODEL.1  VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  TRANSMISSION  \
# 0   2001     0   1.7EL              0          1.7          4             1
# 1   2001     0   1.7EL              0          1.7          4             6
# 2   2001     0   3.2CL              0          3.2          6             4
# 3   2001     0   3.2TL              2          3.2          6             4
# 4   2001     0   3.5RL              2          3.5          6             1
#
#    FUEL  FUEL_CONSUMPTION*  Unnamed: 9  FUEL_CONSUMPTION_COMB(L/100 KM)  \
# 0     3                9.3         7.2                              8.3
# 1     3                8.9         7.4                              8.3
# 2     4               13.7         8.8                             11.5
# 3     4               13.8         8.8                             11.6
# 4     4               15.0        10.9                             13.1
#
#    Unnamed: 11  CO2_EMISSIONS
# 0           34            191
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([("oh", OneHotEncoder(),[0,1,4,5])],remainder = "passthrough")
x = ct.fit_transform(x)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
x.shape
# Out:
# (679, 54)

# %%
np.unique(dataset.dtypes,return_counts=True)
# Out:
# (array([dtype('int32'), dtype('int64'), dtype('float64'), dtype('O')],
#        dtype=object), array([4, 4, 4, 1], dtype=int64))

# %%
for i in cat:
    print("Column :",i)
    print('count of classes :',dataset[i].nunique())
    print(c(dataset[i]))
    print('*'*120)
# Out:
# Column : MODEL.1
# count of classes : 351
# ...

# %%
cat = dataset.dtypes[dataset.dtypes=='O'].index.values
cat
# Out:
# array(['MODEL.1'], dtype=object)

# %%
from collections import Counter as c
dataset["TRANSMISSION"] = np.where(dataset["TRANSMISSION"].isin(["A4","A5","A3"]),"Automatic",dataset["TRANSMISSION"])
dataset["TRANSMISSION"] = np.where(dataset["TRANSMISSION"].isin(["M6","M5"]),"Manual",dataset["TRANSMISSION"])
dataset["TRANSMISSION"] = np.where(dataset["TRANSMISSION"].isin(["AS4","AS5"]),"Automatic with Select Shift",dataset["TRANSMISSION"])
dataset["TRANSMISSION"] = np.where(dataset["TRANSMISSION"].isin(["AV"]),"Continously Variable",dataset["TRANSMISSION"])
c(dataset["TRANSMISSION"])
# Out:
# Counter({'1': 312,
#          '6': 198,
#          '4': 15,
#          '2': 106,
#          '3': 14,
#          '7': 26,
#          '0': 7,
#          '5': 1})

# %%
dataset["FUEL"] = np.where(dataset["FUEL"]=="Z","Premium Gasoline",dataset["FUEL"])
dataset["FUEL"] = np.where(dataset["FUEL"]=="X","Regular Gasoline",dataset["FUEL"])
dataset["FUEL"] = np.where(dataset["FUEL"]=="D","Diesel",dataset["FUEL"])
dataset["FUEL"] = np.where(dataset["FUEL"]=="E","Ethanol(E85)",dataset["FUEL"])
dataset["FUEL"] = np.where(dataset["FUEL"]=="N","Natural Gas",dataset["FUEL"])
c(dataset["FUEL"])
# Out:
# E:\Anaconda\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Counter({'3': 442, '4': 223, '1': 4, '2': 4, '0': 6})

# %%
dataset.dtypes[dataset.dtypes!='0'].index.values
# Out:
# array(['MODEL', 'MAKE', 'MODEL.1', 'VEHICLE CLASS', 'ENGINE_SIZE',
#        'CYLINDERS', 'TRANSMISSION', 'FUEL', 'FUEL_CONSUMPTION*',
#        'Unnamed: 9', 'FUEL_CONSUMPTION_COMB(L/100 KM)', 'Unnamed: 11',
#        'CO2_EMISSIONS'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
x = '*'
for i in cat:
    print("LABEL ENCODING OF:",i)
    LE = LabelEncoder()
    print(c(dataset[i]))
    dataset[i] = LE.fit_transform(dataset[i])
    print(c(data[i]))
    print(x*100)
# Out:
# LABEL ENCODING OF: MODEL.1
# ...

# %%
dataset.isnull().sum()
# Out:
# MODEL                              0
# MAKE                               0
# MODEL.1                            0
# VEHICLE CLASS                      0
# ENGINE_SIZE                        0
# CYLINDERS                          0
# TRANSMISSION                       0
# FUEL                               0
# FUEL_CONSUMPTION*                  0
# Unnamed: 9                         0
# FUEL_CONSUMPTION_COMB(L/100 KM)    0
# Unnamed: 11                        0
# CO2_EMISSIONS                      0
# dtype: int64

# %%
import joblib
joblib.dump(ct,"column")
# Out:
# ['column']

# %%
x[0]
# Out:
# '*'

# %%
import seaborn as sns
corr = dataset.corr()
plt.subplots(figsize=(16,8));
sns.heatmap(corr,annot = True,square = True)
plt.title("correlation matrix of numerical features")
plt.title_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-776-22291d364c2e> in <module>
#       4 sns.heatmap(corr,annot = True,square = True)
#       5 plt.title("correlation matrix of numerical features")
# ----> 6 plt.title_layout()
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title_layout'

# %%
plt.figure(figsize=(16,6))
corr["CO2_EMISSIONS"].sort_values(ascending = True)[:-1].plot(kind = "barh")

# %%
plt.scatter(dataset.MAKE,dataset.CO2_EMISSIONS)
plt.xlabel("MAKE")
plt.ylabel("C02_EMISSIONS")
# Out:
# Text(0, 0.5, 'C02_EMISSIONS')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset["CO2_EMISSIONS"] = le.fit_transform(dataset["CO2_EMISSIONS"])

# %%
x = dataset.iloc[:,0:9].values
y = dataset.iloc[:,9].values

# %%
x
# Out:
# array([[2001, 0, 0, ..., '1', '3', 9.3],
#        [2001, 0, 0, ..., '6', '3', 8.9],
#        [2001, 0, 1, ..., '4', '4', 13.7],
#        ...,
#        [2001, 33, 328, ..., '6', '4', 12.5],
#        [2001, 33, 329, ..., '4', '4', 14.4],
#        [2001, 33, 330, ..., '4', '4', 14.8]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 0)
print(x_train.shape)
print(x_test.shape)
# Out:
# (543, 9)
# (136, 9)

# %%
from sklearn.linear_model  import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_test
# Out:
# array([[2001, 5, 96, ..., '1', '4', 14.7],
#        [2001, 31, 75, ..., '1', '3', 13.5],
#        [2001, 20, 54, ..., '6', '3', 15.4],
#        ...,
#        [2001, 23, 287, ..., '1', '3', 13.8],
#        [2001, 31, 75, ..., '1', '3', 11.5],
#        [2001, 2, 350, ..., '7', '4', 19.4]], dtype=object)

# %%
y_test
# Out:
# array([10.2,  9.5, 12. ,  7.8, 10.3, 12.3,  9.8, 13.9,  9.3,  7.2,  9.4,
#         8.6, 14.7,  9.3, 12.9, 13.5,  9.3,  8.7, 14.6, 11.1, 13. ,  8.7,
#         9.6,  9. , 13.7, 13.1, 11.8, 11.1, 10.5,  9. ,  9. , 10.7, 13.8,
#         8.7,  7.8,  7.9,  9.4, 10.3, 14.5,  8.8,  9. , 10.3, 12. ,  8.3,
#        13.6,  9.3, 10.6,  9. ,  9.8,  9. ,  9.3,  9.6,  8.7, 15.1,  8.5,
#         9.5,  9.3,  7.4, 10.3, 11.1,  8.3,  9.1, 15.4, 10.6,  7.3,  9.3,
#        12.2,  8.2,  9.4, 10.3,  9.3,  9.1, 11.7,  9.6, 12.9, 12.7,  9.4,
#         9. , 14.6, 14.5, 11.9, 10.1,  9.9,  9. ,  9.9,  9.8, 12.5,  9.8,
#         9.8,  9. , 10.2, 10.1, 13. ,  9.7,  9.1, 10.1,  9.5,  9.5, 14.9,
#         9. ,  7. ,  9.1,  7.2,  8.2, 10.3, 13.4, 14.3,  9.4, 10.9, 12.9,
#        13.5, 11.1,  9. , 13.7, 10.7, 11.2,  8.3, 10.6,  6.8, 11. ,  9.1,
#         8.5, 14.6, 10.9,  9. , 15. ,  9.1,  8.8, 11.3, 14.5, 12.9, 10.7,
#         8.9,  9.8,  8.1, 12.3])

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 9.99246576,  9.69170704, 11.08192149,  6.73523946, 10.73876148,
#        12.03553348,  9.90555402, 13.30625707,  9.296602  ,  7.51416547,
#         9.30796329,  8.52465858, 13.58379566,  9.8118509 , 13.63002926,
#        12.16674399,  9.17191989,  8.83750119, 12.81309958, 11.59327078,
#        13.32192233,  9.5062746 ,  9.55174703, 10.26541713, 12.81740277,
#        12.75981343, 11.55326356, 11.26164076,  9.61352452,  9.27807474,
#         8.08863723,  9.93193928, 14.93251821,  7.77152038,  7.46247786,
#         7.41007472, 10.34095332, 10.79245032, 12.83719524,  9.92937224,
#         9.11530523, 10.65375128, 10.92955124,  9.16127941, 13.31447259,
#         9.61193156, 11.34269667,  8.77762165,  9.19024482,  8.86725926,
#         9.63486689,  9.40507207,  8.33489395, 14.6028251 ,  8.67616821,
#         9.68934275,  9.64759714,  5.91673187, 10.53237728, 10.75736161,
#         9.63164288,  8.51979802, 14.02759858, 10.83352141,  7.79419254,
# ...

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("MSE:",metrics.mean_absolute_error(y_test,y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 0.565125909417687
# MSE: 0.565125909417687
# RMSE: 0.7066855068357946

# %%
import pickle
pickle.dump(LinearRegression,open('CO2.pkl','wb'))

# %%
pwd
# Out:
# 'E:\\Geethanjaliexternship'
