# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("E:\Geethanjaliexternship\CO2-Emission-of-Cars-main\Dataset\Sample.csv")

# %%
dataset
# Out:
#      MODEL        MAKE                      MODEL.1             VEHICLE CLASS  \
# 0     2001       ACURA                        1.7EL                   COMPACT
# 1     2001       ACURA                        1.7EL                   COMPACT
# 2     2001       ACURA                        3.2CL                   COMPACT
# 3     2001       ACURA                        3.2TL                  MID-SIZE
# 4     2001       ACURA                        3.5RL                  MID-SIZE
# 5     2001       ACURA                      INTEGRA                SUBCOMPACT
# 6     2001       ACURA                      INTEGRA                SUBCOMPACT
# 7     2001       ACURA                 INTEGRA GS-R                SUBCOMPACT
# 8     2001       ACURA                          MDX                       SUV
# 9     2001       ACURA                          NSX                TWO-SEATER
# 10    2001       ACURA                          NSX                TWO-SEATER
# 11    2001        AUDI                           A4                   COMPACT
# 12    2001        AUDI                           A4                   COMPACT
# 13    2001        AUDI                           A4                   COMPACT
# 14    2001        AUDI                   A4 QUATTRO                   COMPACT
# 15    2001        AUDI                   A4 QUATTRO                   COMPACT
# 16    2001        AUDI                   A4 QUATTRO                   COMPACT
# 17    2001        AUDI                   A4 QUATTRO                   COMPACT
# 18    2001        AUDI                           A6                  MID-SIZE
# 19    2001        AUDI       A6 AVANT QUATTRO WAGON  STATION WAGON - MID-SIZE
# 20    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 21    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 22    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 23    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 24    2001        AUDI                         A8 L                 FULL-SIZE
# 25    2001        AUDI                   A8 QUATTRO                 FULL-SIZE
# 26    2001        AUDI                      ALLROAD                       SUV
# 27    2001        AUDI                      ALLROAD                       SUV
# 28    2001        AUDI                   S4 QUATTRO                   COMPACT
# 29    2001        AUDI                   S4 QUATTRO                   COMPACT
# ..     ...         ...                          ...                       ...
# 649   2001  VOLKSWAGEN               PASSAT 4MOTION                   COMPACT
# 650   2001  VOLKSWAGEN         PASSAT 4MOTION WAGON  STATION WAGON - MID-SIZE
# 651   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 652   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 653   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 654   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 655   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 656   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 657   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 658   2001       VOLVO                    C70 TURBO                   COMPACT
# 659   2001       VOLVO                    C70 TURBO                   COMPACT
# 660   2001       VOLVO                    C70 TURBO                   COMPACT
# 661   2001       VOLVO                    S40 TURBO                   COMPACT
# 662   2001       VOLVO                          S60                   COMPACT
# 663   2001       VOLVO                          S60                   COMPACT
# 664   2001       VOLVO               S60 2.4T TURBO                   COMPACT
# 665   2001       VOLVO               S60 2.4T TURBO                   COMPACT
# 666   2001       VOLVO                 S60 T5 TURBO                   COMPACT
# 667   2001       VOLVO                 S60 T5 TURBO                   COMPACT
# 668   2001       VOLVO        S80/S80 EXECUTIVE 2.9                  MID-SIZE
# 669   2001       VOLVO  S80/S80 EXECUTIVE T-6 TURBO                  MID-SIZE
# 670   2001       VOLVO              V40 WAGON TURBO     STATION WAGON - SMALL
# 671   2001       VOLVO         V70 2.4T WAGON TURBO  STATION WAGON - MID-SIZE
# 672   2001       VOLVO         V70 2.4T WAGON TURBO  STATION WAGON - MID-SIZE
# 673   2001       VOLVO           V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE
# 674   2001       VOLVO           V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE
# 675   2001       VOLVO                    V70 WAGON  STATION WAGON - MID-SIZE
# 676   2001       VOLVO                    V70 WAGON  STATION WAGON - MID-SIZE
# 677   2001       VOLVO          V70 WAGON AWD TURBO  STATION WAGON - MID-SIZE
# 678   2001       VOLVO             V70 XC AWD TURBO                       SUV
#
#      ENGINE_SIZE  CYLINDERS TRANSMISSION FUEL  FUEL_CONSUMPTION*  Unnamed: 9  \
# 0            1.7          4           A4    X                9.3         7.2
# 1            1.7          4           M5    X                8.9         7.4
# 2            3.2          6          AS5    Z               13.7         8.8
# 3            3.2          6          AS5    Z               13.8         8.8
# 4            3.5          6           A4    Z               15.0        10.9
# 5            1.8          4           A4    X               11.4         8.5
# 6            1.8          4           M5    X               10.6         8.3
# 7            1.8          4           M5    Z               10.8         8.5
# 8            3.5          6           A5    Z               15.5        11.1
# 9            3.0          6          AS4    Z               15.3        10.9
# 10           3.2          6           M6    Z               15.6        10.7
# 11           1.8          4           A5    Z               13.2         9.0
# 12           1.8          4           M5    Z               11.8         8.1
# 13           2.8          6           A5    Z               14.6         9.7
# 14           1.8          4           A5    Z               13.3         9.4
# 15           1.8          4           M5    Z               12.2         8.6
# 16           2.8          6           A5    Z               14.9        10.1
# 17           2.8          6           M5    Z               14.3        10.3
# 18           2.8          6           A5    Z               15.0        10.2
# 19           2.8          6           A5    Z               15.4        10.7
# 20           2.7          6           A5    Z               15.2        10.5
# 21           2.7          6           M6    Z               15.2        10.7
# 22           2.8          6           A5    Z               15.4        10.7
# 23           4.2          8           A5    Z               15.4        10.3
# 24           4.2          8           A5    Z               15.4        10.3
# 25           4.2          8           A5    Z               15.4        10.3
# 26           2.7          6           A5    Z               17.1        12.3
# 27           2.7          6           M6    Z               16.5        12.2
# 28           2.7          6           A5    Z               15.2        10.5
# 29           2.7          6           M6    Z               15.2        10.7
# ..           ...        ...          ...  ...                ...         ...
# 649          2.8          6           A5    Z               15.3        10.7
# 650          2.8          6           A5    Z               15.3        10.7
# 651          1.8          4           A5    Z               13.3         9.0
# 652          1.8          4           M5    Z               11.9         8.3
# 653          2.8          6           A5    Z               14.6         9.8
# 654          2.8          6           M5    Z               13.4         8.9
# 655          2.3          5           A5    Z               13.4         9.8
# 656          2.3          5           M5    Z               13.0         9.3
# 657          2.4          5           A5    Z               13.3         9.5
# 658          2.3          5           A5    Z               13.3         9.6
# 659          2.3          5           M5    Z               12.9         9.1
# 660          2.4          5           A5    Z               12.9         9.1
# 661          1.9          4           A5    Z               11.9         8.1
# 662          2.4          5           A5    Z               12.8         9.3
# 663          2.4          5           M5    Z               12.5         9.3
# 664          2.4          5           A5    Z               12.9         9.1
# 665          2.4          5          AS5    Z               12.9         9.1
# 666          2.3          5          AS5    Z               13.3         9.6
# 667          2.3          5           M5    Z               12.9         9.1
# 668          2.9          6           A4    Z               13.6         9.6
# 669          2.8          6          AS4    Z               14.2         9.8
# 670          1.9          4           A5    Z               11.9         8.1
# 671          2.4          5           A5    Z               13.3         9.5
# 672          2.4          5          AS5    Z               13.3         9.5
# 673          2.3          5          AS5    Z               13.4         9.8
# 674          2.3          5           M5    Z               13.0         9.3
# 675          2.4          5           A5    Z               12.8         9.3
# 676          2.4          5           M5    Z               12.5         9.3
# 677          2.4          5          AS5    Z               14.4        10.3
# 678          2.4          5          AS5    Z               14.8        11.4
#
#      Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# 0            8.3           34            191
# 1            8.3           34            191
# 2           11.5           25            265
# 3           11.6           24            267
# 4           13.1           22            301
# 5           10.1           28            232
# 6            9.6           29            221
# 7            9.7           29            223
# 8           13.5           21            311
# 9           13.3           21            306
# 10          13.4           21            308
# 11          11.3           25            260
# 12          10.1           28            232
# 13          12.4           23            285
# 14          11.5           25            265
# 15          10.6           27            244
# 16          12.7           22            292
# 17          12.5           23            288
# 18          12.8           22            294
# 19          13.3           21            306
# 20          13.1           22            301
# 21          13.2           21            304
# 22          13.3           21            306
# 23          13.1           22            301
# 24          13.1           22            301
# 25          13.1           22            301
# 26          15.0           19            345
# 27          14.6           19            336
# 28          13.1           22            301
# 29          13.2           21            304
# ..           ...          ...            ...
# 649         13.3           21            306
# 650         13.3           21            306
# 651         11.4           25            262
# 652         10.3           27            237
# 653         12.4           23            285
# 654         11.4           25            262
# 655         11.8           24            271
# 656         11.3           25            260
# 657         11.6           24            267
# 658         11.6           24            267
# 659         11.2           25            258
# 660         11.2           25            258
# 661         10.2           28            235
# 662         11.2           25            258
# 663         11.0           26            253
# 664         11.2           25            258
# 665         11.2           25            258
# 666         11.6           24            267
# 667         11.2           25            258
# 668         11.8           24            271
# 669         12.2           23            281
# 670         10.2           28            235
# 671         11.6           24            267
# 672         11.6           24            267
# 673         11.8           24            271
# 674         11.3           25            260
# 675         11.2           25            258
# 676         11.0           26            253
# 677         12.5           23            288
# 678         13.3           21            306
#
# [679 rows x 13 columns]

# %%
dataset.head()
# Out:
#    MODEL   MAKE MODEL.1 VEHICLE CLASS  ENGINE_SIZE  CYLINDERS TRANSMISSION  \
# 0   2001  ACURA   1.7EL       COMPACT          1.7          4           A4
# 1   2001  ACURA   1.7EL       COMPACT          1.7          4           M5
# 2   2001  ACURA   3.2CL       COMPACT          3.2          6          AS5
# 3   2001  ACURA   3.2TL      MID-SIZE          3.2          6          AS5
# 4   2001  ACURA   3.5RL      MID-SIZE          3.5          6           A4
#
#   FUEL  FUEL_CONSUMPTION*  Unnamed: 9  Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# 0    X                9.3         7.2          8.3           34            191
# 1    X                8.9         7.4          8.3           34            191
# 2    Z               13.7         8.8         11.5           25            265
# 3    Z               13.8         8.8         11.6           24            267
# 4    Z               15.0        10.9         13.1           22            301

# %%
dataset.rename({'FUEL_CONSUMPTION*':'FUEL_CONSUMPTION_CITY','Unnamed:9':'FUEL_CONSUMPTION_HIGHWAY','Unnamed:11':'FUEL_CONSUMPTION(MPG)'},axis = 1, inplace = True)
dataset
# Out:
#      MODEL        MAKE                      MODEL.1             VEHICLE CLASS  \
# 0     2001       ACURA                        1.7EL                   COMPACT
# 1     2001       ACURA                        1.7EL                   COMPACT
# 2     2001       ACURA                        3.2CL                   COMPACT
# 3     2001       ACURA                        3.2TL                  MID-SIZE
# 4     2001       ACURA                        3.5RL                  MID-SIZE
# 5     2001       ACURA                      INTEGRA                SUBCOMPACT
# 6     2001       ACURA                      INTEGRA                SUBCOMPACT
# 7     2001       ACURA                 INTEGRA GS-R                SUBCOMPACT
# 8     2001       ACURA                          MDX                       SUV
# 9     2001       ACURA                          NSX                TWO-SEATER
# 10    2001       ACURA                          NSX                TWO-SEATER
# 11    2001        AUDI                           A4                   COMPACT
# 12    2001        AUDI                           A4                   COMPACT
# 13    2001        AUDI                           A4                   COMPACT
# 14    2001        AUDI                   A4 QUATTRO                   COMPACT
# 15    2001        AUDI                   A4 QUATTRO                   COMPACT
# 16    2001        AUDI                   A4 QUATTRO                   COMPACT
# 17    2001        AUDI                   A4 QUATTRO                   COMPACT
# 18    2001        AUDI                           A6                  MID-SIZE
# 19    2001        AUDI       A6 AVANT QUATTRO WAGON  STATION WAGON - MID-SIZE
# 20    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 21    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 22    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 23    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 24    2001        AUDI                         A8 L                 FULL-SIZE
# 25    2001        AUDI                   A8 QUATTRO                 FULL-SIZE
# 26    2001        AUDI                      ALLROAD                       SUV
# 27    2001        AUDI                      ALLROAD                       SUV
# 28    2001        AUDI                   S4 QUATTRO                   COMPACT
# 29    2001        AUDI                   S4 QUATTRO                   COMPACT
# ..     ...         ...                          ...                       ...
# 649   2001  VOLKSWAGEN               PASSAT 4MOTION                   COMPACT
# 650   2001  VOLKSWAGEN         PASSAT 4MOTION WAGON  STATION WAGON - MID-SIZE
# 651   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 652   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 653   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 654   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 655   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 656   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 657   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 658   2001       VOLVO                    C70 TURBO                   COMPACT
# 659   2001       VOLVO                    C70 TURBO                   COMPACT
# 660   2001       VOLVO                    C70 TURBO                   COMPACT
# 661   2001       VOLVO                    S40 TURBO                   COMPACT
# 662   2001       VOLVO                          S60                   COMPACT
# 663   2001       VOLVO                          S60                   COMPACT
# 664   2001       VOLVO               S60 2.4T TURBO                   COMPACT
# 665   2001       VOLVO               S60 2.4T TURBO                   COMPACT
# 666   2001       VOLVO                 S60 T5 TURBO                   COMPACT
# 667   2001       VOLVO                 S60 T5 TURBO                   COMPACT
# 668   2001       VOLVO        S80/S80 EXECUTIVE 2.9                  MID-SIZE
# 669   2001       VOLVO  S80/S80 EXECUTIVE T-6 TURBO                  MID-SIZE
# 670   2001       VOLVO              V40 WAGON TURBO     STATION WAGON - SMALL
# 671   2001       VOLVO         V70 2.4T WAGON TURBO  STATION WAGON - MID-SIZE
# 672   2001       VOLVO         V70 2.4T WAGON TURBO  STATION WAGON - MID-SIZE
# 673   2001       VOLVO           V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE
# 674   2001       VOLVO           V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE
# 675   2001       VOLVO                    V70 WAGON  STATION WAGON - MID-SIZE
# 676   2001       VOLVO                    V70 WAGON  STATION WAGON - MID-SIZE
# 677   2001       VOLVO          V70 WAGON AWD TURBO  STATION WAGON - MID-SIZE
# 678   2001       VOLVO             V70 XC AWD TURBO                       SUV
#
#      ENGINE_SIZE  CYLINDERS TRANSMISSION FUEL  FUEL_CONSUMPTION_CITY  \
# 0            1.7          4           A4    X                    9.3
# 1            1.7          4           M5    X                    8.9
# 2            3.2          6          AS5    Z                   13.7
# 3            3.2          6          AS5    Z                   13.8
# 4            3.5          6           A4    Z                   15.0
# 5            1.8          4           A4    X                   11.4
# 6            1.8          4           M5    X                   10.6
# 7            1.8          4           M5    Z                   10.8
# 8            3.5          6           A5    Z                   15.5
# 9            3.0          6          AS4    Z                   15.3
# 10           3.2          6           M6    Z                   15.6
# 11           1.8          4           A5    Z                   13.2
# 12           1.8          4           M5    Z                   11.8
# 13           2.8          6           A5    Z                   14.6
# 14           1.8          4           A5    Z                   13.3
# 15           1.8          4           M5    Z                   12.2
# 16           2.8          6           A5    Z                   14.9
# 17           2.8          6           M5    Z                   14.3
# 18           2.8          6           A5    Z                   15.0
# 19           2.8          6           A5    Z                   15.4
# 20           2.7          6           A5    Z                   15.2
# 21           2.7          6           M6    Z                   15.2
# 22           2.8          6           A5    Z                   15.4
# 23           4.2          8           A5    Z                   15.4
# 24           4.2          8           A5    Z                   15.4
# 25           4.2          8           A5    Z                   15.4
# 26           2.7          6           A5    Z                   17.1
# 27           2.7          6           M6    Z                   16.5
# 28           2.7          6           A5    Z                   15.2
# 29           2.7          6           M6    Z                   15.2
# ..           ...        ...          ...  ...                    ...
# 649          2.8          6           A5    Z                   15.3
# 650          2.8          6           A5    Z                   15.3
# 651          1.8          4           A5    Z                   13.3
# 652          1.8          4           M5    Z                   11.9
# 653          2.8          6           A5    Z                   14.6
# 654          2.8          6           M5    Z                   13.4
# 655          2.3          5           A5    Z                   13.4
# 656          2.3          5           M5    Z                   13.0
# 657          2.4          5           A5    Z                   13.3
# 658          2.3          5           A5    Z                   13.3
# 659          2.3          5           M5    Z                   12.9
# 660          2.4          5           A5    Z                   12.9
# 661          1.9          4           A5    Z                   11.9
# 662          2.4          5           A5    Z                   12.8
# 663          2.4          5           M5    Z                   12.5
# 664          2.4          5           A5    Z                   12.9
# 665          2.4          5          AS5    Z                   12.9
# 666          2.3          5          AS5    Z                   13.3
# 667          2.3          5           M5    Z                   12.9
# 668          2.9          6           A4    Z                   13.6
# 669          2.8          6          AS4    Z                   14.2
# 670          1.9          4           A5    Z                   11.9
# 671          2.4          5           A5    Z                   13.3
# 672          2.4          5          AS5    Z                   13.3
# 673          2.3          5          AS5    Z                   13.4
# 674          2.3          5           M5    Z                   13.0
# 675          2.4          5           A5    Z                   12.8
# 676          2.4          5           M5    Z                   12.5
# 677          2.4          5          AS5    Z                   14.4
# 678          2.4          5          AS5    Z                   14.8
#
#      Unnamed: 9  Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# 0           7.2          8.3           34            191
# 1           7.4          8.3           34            191
# 2           8.8         11.5           25            265
# 3           8.8         11.6           24            267
# 4          10.9         13.1           22            301
# 5           8.5         10.1           28            232
# 6           8.3          9.6           29            221
# 7           8.5          9.7           29            223
# 8          11.1         13.5           21            311
# 9          10.9         13.3           21            306
# 10         10.7         13.4           21            308
# 11          9.0         11.3           25            260
# 12          8.1         10.1           28            232
# 13          9.7         12.4           23            285
# 14          9.4         11.5           25            265
# 15          8.6         10.6           27            244
# 16         10.1         12.7           22            292
# 17         10.3         12.5           23            288
# 18         10.2         12.8           22            294
# 19         10.7         13.3           21            306
# 20         10.5         13.1           22            301
# 21         10.7         13.2           21            304
# 22         10.7         13.3           21            306
# 23         10.3         13.1           22            301
# 24         10.3         13.1           22            301
# 25         10.3         13.1           22            301
# 26         12.3         15.0           19            345
# 27         12.2         14.6           19            336
# 28         10.5         13.1           22            301
# 29         10.7         13.2           21            304
# ..          ...          ...          ...            ...
# 649        10.7         13.3           21            306
# 650        10.7         13.3           21            306
# 651         9.0         11.4           25            262
# 652         8.3         10.3           27            237
# 653         9.8         12.4           23            285
# 654         8.9         11.4           25            262
# 655         9.8         11.8           24            271
# 656         9.3         11.3           25            260
# 657         9.5         11.6           24            267
# 658         9.6         11.6           24            267
# 659         9.1         11.2           25            258
# 660         9.1         11.2           25            258
# 661         8.1         10.2           28            235
# 662         9.3         11.2           25            258
# 663         9.3         11.0           26            253
# 664         9.1         11.2           25            258
# 665         9.1         11.2           25            258
# 666         9.6         11.6           24            267
# 667         9.1         11.2           25            258
# 668         9.6         11.8           24            271
# 669         9.8         12.2           23            281
# 670         8.1         10.2           28            235
# 671         9.5         11.6           24            267
# 672         9.5         11.6           24            267
# 673         9.8         11.8           24            271
# 674         9.3         11.3           25            260
# 675         9.3         11.2           25            258
# 676         9.3         11.0           26            253
# 677        10.3         12.5           23            288
# 678        11.4         13.3           21            306
#
# [679 rows x 13 columns]

# %%
dataset
# Out:
#      MODEL        MAKE                      MODEL.1             VEHICLE CLASS  \
# 0     2001       ACURA                        1.7EL                   COMPACT
# 1     2001       ACURA                        1.7EL                   COMPACT
# 2     2001       ACURA                        3.2CL                   COMPACT
# 3     2001       ACURA                        3.2TL                  MID-SIZE
# 4     2001       ACURA                        3.5RL                  MID-SIZE
# 5     2001       ACURA                      INTEGRA                SUBCOMPACT
# 6     2001       ACURA                      INTEGRA                SUBCOMPACT
# 7     2001       ACURA                 INTEGRA GS-R                SUBCOMPACT
# 8     2001       ACURA                          MDX                       SUV
# 9     2001       ACURA                          NSX                TWO-SEATER
# 10    2001       ACURA                          NSX                TWO-SEATER
# 11    2001        AUDI                           A4                   COMPACT
# 12    2001        AUDI                           A4                   COMPACT
# 13    2001        AUDI                           A4                   COMPACT
# 14    2001        AUDI                   A4 QUATTRO                   COMPACT
# 15    2001        AUDI                   A4 QUATTRO                   COMPACT
# 16    2001        AUDI                   A4 QUATTRO                   COMPACT
# 17    2001        AUDI                   A4 QUATTRO                   COMPACT
# 18    2001        AUDI                           A6                  MID-SIZE
# 19    2001        AUDI       A6 AVANT QUATTRO WAGON  STATION WAGON - MID-SIZE
# 20    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 21    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 22    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 23    2001        AUDI                   A6 QUATTRO                  MID-SIZE
# 24    2001        AUDI                         A8 L                 FULL-SIZE
# 25    2001        AUDI                   A8 QUATTRO                 FULL-SIZE
# 26    2001        AUDI                      ALLROAD                       SUV
# 27    2001        AUDI                      ALLROAD                       SUV
# 28    2001        AUDI                   S4 QUATTRO                   COMPACT
# 29    2001        AUDI                   S4 QUATTRO                   COMPACT
# ..     ...         ...                          ...                       ...
# 649   2001  VOLKSWAGEN               PASSAT 4MOTION                   COMPACT
# 650   2001  VOLKSWAGEN         PASSAT 4MOTION WAGON  STATION WAGON - MID-SIZE
# 651   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 652   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 653   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 654   2001  VOLKSWAGEN                 PASSAT WAGON  STATION WAGON - MID-SIZE
# 655   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 656   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 657   2001       VOLVO        C70 CONVERTIBLE TURBO                SUBCOMPACT
# 658   2001       VOLVO                    C70 TURBO                   COMPACT
# 659   2001       VOLVO                    C70 TURBO                   COMPACT
# 660   2001       VOLVO                    C70 TURBO                   COMPACT
# 661   2001       VOLVO                    S40 TURBO                   COMPACT
# 662   2001       VOLVO                          S60                   COMPACT
# 663   2001       VOLVO                          S60                   COMPACT
# 664   2001       VOLVO               S60 2.4T TURBO                   COMPACT
# 665   2001       VOLVO               S60 2.4T TURBO                   COMPACT
# 666   2001       VOLVO                 S60 T5 TURBO                   COMPACT
# 667   2001       VOLVO                 S60 T5 TURBO                   COMPACT
# 668   2001       VOLVO        S80/S80 EXECUTIVE 2.9                  MID-SIZE
# 669   2001       VOLVO  S80/S80 EXECUTIVE T-6 TURBO                  MID-SIZE
# 670   2001       VOLVO              V40 WAGON TURBO     STATION WAGON - SMALL
# 671   2001       VOLVO         V70 2.4T WAGON TURBO  STATION WAGON - MID-SIZE
# 672   2001       VOLVO         V70 2.4T WAGON TURBO  STATION WAGON - MID-SIZE
# 673   2001       VOLVO           V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE
# 674   2001       VOLVO           V70 T5 WAGON TURBO  STATION WAGON - MID-SIZE
# 675   2001       VOLVO                    V70 WAGON  STATION WAGON - MID-SIZE
# 676   2001       VOLVO                    V70 WAGON  STATION WAGON - MID-SIZE
# 677   2001       VOLVO          V70 WAGON AWD TURBO  STATION WAGON - MID-SIZE
# 678   2001       VOLVO             V70 XC AWD TURBO                       SUV
#
#      ENGINE_SIZE  CYLINDERS TRANSMISSION FUEL  FUEL_CONSUMPTION_CITY  \
# 0            1.7          4           A4    X                    9.3
# 1            1.7          4           M5    X                    8.9
# 2            3.2          6          AS5    Z                   13.7
# 3            3.2          6          AS5    Z                   13.8
# 4            3.5          6           A4    Z                   15.0
# 5            1.8          4           A4    X                   11.4
# 6            1.8          4           M5    X                   10.6
# 7            1.8          4           M5    Z                   10.8
# 8            3.5          6           A5    Z                   15.5
# 9            3.0          6          AS4    Z                   15.3
# 10           3.2          6           M6    Z                   15.6
# 11           1.8          4           A5    Z                   13.2
# 12           1.8          4           M5    Z                   11.8
# 13           2.8          6           A5    Z                   14.6
# 14           1.8          4           A5    Z                   13.3
# 15           1.8          4           M5    Z                   12.2
# 16           2.8          6           A5    Z                   14.9
# 17           2.8          6           M5    Z                   14.3
# 18           2.8          6           A5    Z                   15.0
# 19           2.8          6           A5    Z                   15.4
# 20           2.7          6           A5    Z                   15.2
# 21           2.7          6           M6    Z                   15.2
# 22           2.8          6           A5    Z                   15.4
# 23           4.2          8           A5    Z                   15.4
# 24           4.2          8           A5    Z                   15.4
# 25           4.2          8           A5    Z                   15.4
# 26           2.7          6           A5    Z                   17.1
# 27           2.7          6           M6    Z                   16.5
# 28           2.7          6           A5    Z                   15.2
# 29           2.7          6           M6    Z                   15.2
# ..           ...        ...          ...  ...                    ...
# 649          2.8          6           A5    Z                   15.3
# 650          2.8          6           A5    Z                   15.3
# 651          1.8          4           A5    Z                   13.3
# 652          1.8          4           M5    Z                   11.9
# 653          2.8          6           A5    Z                   14.6
# 654          2.8          6           M5    Z                   13.4
# 655          2.3          5           A5    Z                   13.4
# 656          2.3          5           M5    Z                   13.0
# 657          2.4          5           A5    Z                   13.3
# 658          2.3          5           A5    Z                   13.3
# 659          2.3          5           M5    Z                   12.9
# 660          2.4          5           A5    Z                   12.9
# 661          1.9          4           A5    Z                   11.9
# 662          2.4          5           A5    Z                   12.8
# 663          2.4          5           M5    Z                   12.5
# 664          2.4          5           A5    Z                   12.9
# 665          2.4          5          AS5    Z                   12.9
# 666          2.3          5          AS5    Z                   13.3
# 667          2.3          5           M5    Z                   12.9
# 668          2.9          6           A4    Z                   13.6
# 669          2.8          6          AS4    Z                   14.2
# 670          1.9          4           A5    Z                   11.9
# 671          2.4          5           A5    Z                   13.3
# 672          2.4          5          AS5    Z                   13.3
# 673          2.3          5          AS5    Z                   13.4
# 674          2.3          5           M5    Z                   13.0
# 675          2.4          5           A5    Z                   12.8
# 676          2.4          5           M5    Z                   12.5
# 677          2.4          5          AS5    Z                   14.4
# 678          2.4          5          AS5    Z                   14.8
#
#      Unnamed: 9  Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# 0           7.2          8.3           34            191
# 1           7.4          8.3           34            191
# 2           8.8         11.5           25            265
# 3           8.8         11.6           24            267
# 4          10.9         13.1           22            301
# 5           8.5         10.1           28            232
# 6           8.3          9.6           29            221
# 7           8.5          9.7           29            223
# 8          11.1         13.5           21            311
# 9          10.9         13.3           21            306
# 10         10.7         13.4           21            308
# 11          9.0         11.3           25            260
# 12          8.1         10.1           28            232
# 13          9.7         12.4           23            285
# 14          9.4         11.5           25            265
# 15          8.6         10.6           27            244
# 16         10.1         12.7           22            292
# 17         10.3         12.5           23            288
# 18         10.2         12.8           22            294
# 19         10.7         13.3           21            306
# 20         10.5         13.1           22            301
# 21         10.7         13.2           21            304
# 22         10.7         13.3           21            306
# 23         10.3         13.1           22            301
# 24         10.3         13.1           22            301
# 25         10.3         13.1           22            301
# 26         12.3         15.0           19            345
# 27         12.2         14.6           19            336
# 28         10.5         13.1           22            301
# 29         10.7         13.2           21            304
# ..          ...          ...          ...            ...
# 649        10.7         13.3           21            306
# 650        10.7         13.3           21            306
# 651         9.0         11.4           25            262
# 652         8.3         10.3           27            237
# 653         9.8         12.4           23            285
# 654         8.9         11.4           25            262
# 655         9.8         11.8           24            271
# 656         9.3         11.3           25            260
# 657         9.5         11.6           24            267
# 658         9.6         11.6           24            267
# 659         9.1         11.2           25            258
# 660         9.1         11.2           25            258
# 661         8.1         10.2           28            235
# 662         9.3         11.2           25            258
# 663         9.3         11.0           26            253
# 664         9.1         11.2           25            258
# 665         9.1         11.2           25            258
# 666         9.6         11.6           24            267
# 667         9.1         11.2           25            258
# 668         9.6         11.8           24            271
# 669         9.8         12.2           23            281
# 670         8.1         10.2           28            235
# 671         9.5         11.6           24            267
# 672         9.5         11.6           24            267
# 673         9.8         11.8           24            271
# 674         9.3         11.3           25            260
# 675         9.3         11.2           25            258
# 676         9.3         11.0           26            253
# 677        10.3         12.5           23            288
# 678        11.4         13.3           21            306
#
# [679 rows x 13 columns]

# %%
dataset.isnull().any()
# Out:
# MODEL                    False
# MAKE                     False
# MODEL.1                  False
# VEHICLE CLASS            False
# ENGINE_SIZE              False
# CYLINDERS                False
# TRANSMISSION             False
# FUEL                     False
# FUEL_CONSUMPTION_CITY    False
# Unnamed: 9               False
# Unnamed: 10              False
# Unnamed: 11              False
# CO2_EMISSIONS            False
# dtype: bool

# %%
np.unique(dataset.dtypes,return_counts=True)
# Out:
# (array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object),
#  array([4, 4, 5], dtype=int64))

# %%
cat = dataset.dtypes[dataset.dtypes== '0'].index.values

# %%
cat
# Out:
# array([], dtype=object)

# %%
for i in cat:
    print("Column :",i)
    print('count of classes :',dataset[i].nunique())
    print(c(dataset[i]))
    print('*'*120)

# %%
from collections import Counter as c
dataset["TRANSMISSION"] = np.where(dataset["TRANSMISSION"].isin(["A4","A5","A3"]),"Automatic",dataset["TRANSMISSION"])
dataset["TRANSMISSION"] = np.where(dataset["TRANSMISSION"].isin(["M6","M5"]),"Manual",dataset["TRANSMISSION"])
dataset["TRANSMISSION"] = np.where(dataset["TRANSMISSION"].isin(["AS4","AS5"]),"Automatic with Select Shift",dataset["TRANSMISSION"])
dataset["TRANSMISSION"] = np.where(dataset["TRANSMISSION"].isin(["AV"]),"Continously Variable",dataset["TRANSMISSION"])
c(dataset["TRANSMISSION"])
# Out:
# Counter({'Automatic': 425,
#          'Manual': 224,
#          'Automatic with Select Shift': 29,
#          'Continously Variable': 1})

# %%
dataset["FUEL"] = np.where(dataset["FUEL"]=="Z","Premium Gasoline",dataset["FUEL"])
dataset["FUEL"] = np.where(dataset["FUEL"]=="X","Regular Gasoline",dataset["FUEL"])
dataset["FUEL"] = np.where(dataset["FUEL"]=="D","Diesel",dataset["FUEL"])
dataset["FUEL"] = np.where(dataset["FUEL"]=="E","Ethanol(E85)",dataset["FUEL"])
dataset["FUEL"] = np.where(dataset["FUEL"]=="N","Natural Gas",dataset["FUEL"])
c(dataset["FUEL"])
# Out:
# Counter({'Regular Gasoline': 442,
#          'Premium Gasoline': 223,
#          'Ethanol(E85)': 4,
#          'Natural Gas': 4,
#          'Diesel': 6})

# %%
dataset.dtypes[dataset.dtypes!='0'].index.values
# Out:
# array(['MODEL', 'MAKE', 'MODEL.1', 'VEHICLE CLASS', 'ENGINE_SIZE',
#        'CYLINDERS', 'TRANSMISSION', 'FUEL', 'FUEL_CONSUMPTION_CITY',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'CO2_EMISSIONS'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
x = '*'
for i in cat:
    print("LABEL ENCODING OF:",i)
    LE = LabelEncoder()
    print(c(dataset[i]))
    dataset[i] = LE.fit_transform(dataset[i])
    print(c(data[i]))
    print(x*100)

# %%
plt.scatter(dataset.MAKE,dataset.CO2_EMISSIONS)
plt.xlabel("MAKE")
plt.ylabel("C02_EMISSIONS")
# Out:
# Text(0, 0.5, 'C02_EMISSIONS')

# %%
import seaborn as sns
corr = dataset.corr()
plt.subplots(figsize=(16,8));
sns.heatmap(corr,annot = True,square = True)
plt.title("correlation matrix of numerical features")
plt.title_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-22291d364c2e> in <module>
#       4 sns.heatmap(corr,annot = True,square = True)
#       5 plt.title("correlation matrix of numerical features")
# ----> 6 plt.title_layout()
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'title_layout'

# %%
dataset.drop(columns=['MODEL','MODEL.1','Unnamed: 9'], inplace = True)
dataset
# Out:
#            MAKE             VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  \
# 0         ACURA                   COMPACT          1.7          4
# 1         ACURA                   COMPACT          1.7          4
# 2         ACURA                   COMPACT          3.2          6
# 3         ACURA                  MID-SIZE          3.2          6
# 4         ACURA                  MID-SIZE          3.5          6
# 5         ACURA                SUBCOMPACT          1.8          4
# 6         ACURA                SUBCOMPACT          1.8          4
# 7         ACURA                SUBCOMPACT          1.8          4
# 8         ACURA                       SUV          3.5          6
# 9         ACURA                TWO-SEATER          3.0          6
# 10        ACURA                TWO-SEATER          3.2          6
# 11         AUDI                   COMPACT          1.8          4
# 12         AUDI                   COMPACT          1.8          4
# 13         AUDI                   COMPACT          2.8          6
# 14         AUDI                   COMPACT          1.8          4
# 15         AUDI                   COMPACT          1.8          4
# 16         AUDI                   COMPACT          2.8          6
# 17         AUDI                   COMPACT          2.8          6
# 18         AUDI                  MID-SIZE          2.8          6
# 19         AUDI  STATION WAGON - MID-SIZE          2.8          6
# 20         AUDI                  MID-SIZE          2.7          6
# 21         AUDI                  MID-SIZE          2.7          6
# 22         AUDI                  MID-SIZE          2.8          6
# 23         AUDI                  MID-SIZE          4.2          8
# 24         AUDI                 FULL-SIZE          4.2          8
# 25         AUDI                 FULL-SIZE          4.2          8
# 26         AUDI                       SUV          2.7          6
# 27         AUDI                       SUV          2.7          6
# 28         AUDI                   COMPACT          2.7          6
# 29         AUDI                   COMPACT          2.7          6
# ..          ...                       ...          ...        ...
# 649  VOLKSWAGEN                   COMPACT          2.8          6
# 650  VOLKSWAGEN  STATION WAGON - MID-SIZE          2.8          6
# 651  VOLKSWAGEN  STATION WAGON - MID-SIZE          1.8          4
# 652  VOLKSWAGEN  STATION WAGON - MID-SIZE          1.8          4
# 653  VOLKSWAGEN  STATION WAGON - MID-SIZE          2.8          6
# 654  VOLKSWAGEN  STATION WAGON - MID-SIZE          2.8          6
# 655       VOLVO                SUBCOMPACT          2.3          5
# 656       VOLVO                SUBCOMPACT          2.3          5
# 657       VOLVO                SUBCOMPACT          2.4          5
# 658       VOLVO                   COMPACT          2.3          5
# 659       VOLVO                   COMPACT          2.3          5
# 660       VOLVO                   COMPACT          2.4          5
# 661       VOLVO                   COMPACT          1.9          4
# 662       VOLVO                   COMPACT          2.4          5
# 663       VOLVO                   COMPACT          2.4          5
# 664       VOLVO                   COMPACT          2.4          5
# 665       VOLVO                   COMPACT          2.4          5
# 666       VOLVO                   COMPACT          2.3          5
# 667       VOLVO                   COMPACT          2.3          5
# 668       VOLVO                  MID-SIZE          2.9          6
# 669       VOLVO                  MID-SIZE          2.8          6
# 670       VOLVO     STATION WAGON - SMALL          1.9          4
# 671       VOLVO  STATION WAGON - MID-SIZE          2.4          5
# 672       VOLVO  STATION WAGON - MID-SIZE          2.4          5
# 673       VOLVO  STATION WAGON - MID-SIZE          2.3          5
# 674       VOLVO  STATION WAGON - MID-SIZE          2.3          5
# 675       VOLVO  STATION WAGON - MID-SIZE          2.4          5
# 676       VOLVO  STATION WAGON - MID-SIZE          2.4          5
# 677       VOLVO  STATION WAGON - MID-SIZE          2.4          5
# 678       VOLVO                       SUV          2.4          5
#
#                     TRANSMISSION              FUEL  FUEL_CONSUMPTION_CITY  \
# 0                      Automatic  Regular Gasoline                    9.3
# 1                         Manual  Regular Gasoline                    8.9
# 2    Automatic with Select Shift  Premium Gasoline                   13.7
# 3    Automatic with Select Shift  Premium Gasoline                   13.8
# 4                      Automatic  Premium Gasoline                   15.0
# 5                      Automatic  Regular Gasoline                   11.4
# 6                         Manual  Regular Gasoline                   10.6
# 7                         Manual  Premium Gasoline                   10.8
# 8                      Automatic  Premium Gasoline                   15.5
# 9    Automatic with Select Shift  Premium Gasoline                   15.3
# 10                        Manual  Premium Gasoline                   15.6
# 11                     Automatic  Premium Gasoline                   13.2
# 12                        Manual  Premium Gasoline                   11.8
# 13                     Automatic  Premium Gasoline                   14.6
# 14                     Automatic  Premium Gasoline                   13.3
# 15                        Manual  Premium Gasoline                   12.2
# 16                     Automatic  Premium Gasoline                   14.9
# 17                        Manual  Premium Gasoline                   14.3
# 18                     Automatic  Premium Gasoline                   15.0
# 19                     Automatic  Premium Gasoline                   15.4
# 20                     Automatic  Premium Gasoline                   15.2
# 21                        Manual  Premium Gasoline                   15.2
# 22                     Automatic  Premium Gasoline                   15.4
# 23                     Automatic  Premium Gasoline                   15.4
# 24                     Automatic  Premium Gasoline                   15.4
# 25                     Automatic  Premium Gasoline                   15.4
# 26                     Automatic  Premium Gasoline                   17.1
# 27                        Manual  Premium Gasoline                   16.5
# 28                     Automatic  Premium Gasoline                   15.2
# 29                        Manual  Premium Gasoline                   15.2
# ..                           ...               ...                    ...
# 649                    Automatic  Premium Gasoline                   15.3
# 650                    Automatic  Premium Gasoline                   15.3
# 651                    Automatic  Premium Gasoline                   13.3
# 652                       Manual  Premium Gasoline                   11.9
# 653                    Automatic  Premium Gasoline                   14.6
# 654                       Manual  Premium Gasoline                   13.4
# 655                    Automatic  Premium Gasoline                   13.4
# 656                       Manual  Premium Gasoline                   13.0
# 657                    Automatic  Premium Gasoline                   13.3
# 658                    Automatic  Premium Gasoline                   13.3
# 659                       Manual  Premium Gasoline                   12.9
# 660                    Automatic  Premium Gasoline                   12.9
# 661                    Automatic  Premium Gasoline                   11.9
# 662                    Automatic  Premium Gasoline                   12.8
# 663                       Manual  Premium Gasoline                   12.5
# 664                    Automatic  Premium Gasoline                   12.9
# 665  Automatic with Select Shift  Premium Gasoline                   12.9
# 666  Automatic with Select Shift  Premium Gasoline                   13.3
# 667                       Manual  Premium Gasoline                   12.9
# 668                    Automatic  Premium Gasoline                   13.6
# 669  Automatic with Select Shift  Premium Gasoline                   14.2
# 670                    Automatic  Premium Gasoline                   11.9
# 671                    Automatic  Premium Gasoline                   13.3
# 672  Automatic with Select Shift  Premium Gasoline                   13.3
# 673  Automatic with Select Shift  Premium Gasoline                   13.4
# 674                       Manual  Premium Gasoline                   13.0
# 675                    Automatic  Premium Gasoline                   12.8
# 676                       Manual  Premium Gasoline                   12.5
# 677  Automatic with Select Shift  Premium Gasoline                   14.4
# 678  Automatic with Select Shift  Premium Gasoline                   14.8
#
#      Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# 0            8.3           34            191
# 1            8.3           34            191
# 2           11.5           25            265
# 3           11.6           24            267
# 4           13.1           22            301
# 5           10.1           28            232
# 6            9.6           29            221
# 7            9.7           29            223
# 8           13.5           21            311
# 9           13.3           21            306
# 10          13.4           21            308
# 11          11.3           25            260
# 12          10.1           28            232
# 13          12.4           23            285
# 14          11.5           25            265
# 15          10.6           27            244
# 16          12.7           22            292
# 17          12.5           23            288
# 18          12.8           22            294
# 19          13.3           21            306
# 20          13.1           22            301
# 21          13.2           21            304
# 22          13.3           21            306
# 23          13.1           22            301
# 24          13.1           22            301
# 25          13.1           22            301
# 26          15.0           19            345
# 27          14.6           19            336
# 28          13.1           22            301
# 29          13.2           21            304
# ..           ...          ...            ...
# 649         13.3           21            306
# 650         13.3           21            306
# 651         11.4           25            262
# 652         10.3           27            237
# 653         12.4           23            285
# 654         11.4           25            262
# 655         11.8           24            271
# 656         11.3           25            260
# 657         11.6           24            267
# 658         11.6           24            267
# 659         11.2           25            258
# 660         11.2           25            258
# 661         10.2           28            235
# 662         11.2           25            258
# 663         11.0           26            253
# 664         11.2           25            258
# 665         11.2           25            258
# 666         11.6           24            267
# 667         11.2           25            258
# 668         11.8           24            271
# 669         12.2           23            281
# 670         10.2           28            235
# 671         11.6           24            267
# 672         11.6           24            267
# 673         11.8           24            271
# 674         11.3           25            260
# 675         11.2           25            258
# 676         11.0           26            253
# 677         12.5           23            288
# 678         13.3           21            306
#
# [679 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dataset["MAKE"] = le.fit_transform(dataset["MAKE"])
dataset["VEHICLE CLASS"] = le.fit_transform(dataset["VEHICLE CLASS"])
dataset["TRANSMISSION"] = le.fit_transform(dataset["TRANSMISSION"])
dataset["FUEL"] = le.fit_transform(dataset["FUEL"])

# %%
dataset.head()
# Out:
#    MAKE  VEHICLE CLASS  ENGINE_SIZE  CYLINDERS  TRANSMISSION  FUEL  \
# 0     0              0          1.7          4             0     4
# 1     0              0          1.7          4             3     4
# 2     0              0          3.2          6             1     3
# 3     0              2          3.2          6             1     3
# 4     0              2          3.5          6             0     3
#
#    FUEL_CONSUMPTION_CITY  Unnamed: 10  Unnamed: 11  CO2_EMISSIONS
# 0                    9.3          8.3           34            191
# 1                    8.9          8.3           34            191
# 2                   13.7         11.5           25            265
# 3                   13.8         11.6           24            267
# 4                   15.0         13.1           22            301

# %%
x = dataset.iloc[:,0:9].values
y = dataset.iloc[:,9].values

# %%
x
# Out:
# array([[ 0. ,  0. ,  1.7, ...,  9.3,  8.3, 34. ],
#        [ 0. ,  0. ,  1.7, ...,  8.9,  8.3, 34. ],
#        [ 0. ,  0. ,  3.2, ..., 13.7, 11.5, 25. ],
#        ...,
#        [33. ,  7. ,  2.4, ..., 12.5, 11. , 26. ],
#        [33. ,  7. ,  2.4, ..., 14.4, 12.5, 23. ],
#        [33. , 10. ,  2.4, ..., 14.8, 13.3, 21. ]])

# %%
y
# Out:
# array([191, 191, 265, 267, 301, 232, 221, 223, 311, 306, 308, 260, 232,
#        285, 265, 244, 292, 288, 294, 306, 301, 304, 306, 301, 301, 301,
#        345, 336, 301, 304, 347, 260, 260, 246, 260, 258, 251, 265, 253,
#        274, 274, 265, 253, 274, 271, 260, 251, 281, 290, 260, 251, 290,
#        267, 265, 253, 274, 274, 281, 251, 294, 317, 320, 308, 308, 373,
#        299, 299, 315, 324, 373, 338, 347, 375, 267, 265, 274, 253, 373,
#        258, 265, 265, 278, 271, 278, 308, 294, 294, 294, 313, 350, 324,
#        370, 313, 343, 350, 386, 324, 347, 347, 368, 366, 391, 357, 391,
#        262, 262, 292, 274, 235, 239, 255, 246, 235, 292, 274, 368, 389,
#        398, 380, 389, 407, 239, 271, 350, 386, 357, 409, 377, 403, 357,
#        396, 258, 239, 271, 313, 343, 380, 384, 283, 275, 260, 245, 228,
#        251, 253, 251, 253, 276, 288, 265, 278, 265, 262, 278, 288, 288,
#        230, 205, 216, 276, 269, 253, 265, 262, 265, 262, 262, 274, 274,
#        260, 299, 306, 315, 216, 205, 225, 207, 265, 258, 239, 237, 239,
#        237, 299, 343, 347, 352, 368, 354, 414, 373, 361, 391, 377, 428,
#        432, 403, 428, 428, 299, 306, 306, 315, 317, 347, 347, 359, 350,
#        398, 396, 393, 421, 414, 435, 439, 426, 384, 396, 423, 400, 396,
#        400, 396, 423, 355, 435, 423, 359, 419, 419, 260, 251, 294, 274,
#        363, 363, 412, 363, 338, 363, 363, 430, 378, 239, 294, 253, 301,
#        357, 340, 320, 357, 340, 382, 426, 357, 373, 338, 336, 340, 354,
#        363, 354, 357, 361, 377, 398, 214, 196, 223, 219, 214, 196, 223,
#        219, 294, 274, 267, 294, 297, 304, 327, 311, 324, 317, 361, 329,
#        359, 350, 283, 269, 290, 283, 299, 324, 347, 347, 368, 363, 357,
#        391, 391, 368, 389, 398, 380, 389, 407, 313, 343, 350, 386, 350,
#        386, 357, 409, 377, 478, 391, 403, 453, 403, 453, 313, 350, 324,
#        370, 313, 338, 380, 384, 283, 275, 260, 245, 239, 223, 260, 189,
#        179, 191, 191, 267, 267, 104, 294, 260, 251, 269, 214, 196, 212,
#        198, 219, 219, 292, 258, 267, 246, 230, 278, 235, 230, 271, 304,
#        363, 334, 336, 359, 366, 292, 301, 306, 306, 306, 327, 306, 306,
#        327, 327, 352, 313, 338, 370, 343, 352, 311, 370, 352, 267, 253,
#        281, 262, 221, 209, 239, 239, 306, 288, 276, 299, 297, 304, 290,
#        421, 294, 304, 297, 306, 288, 311, 313, 449, 294, 258, 221, 278,
#        271, 327, 311, 336, 320, 359, 350, 276, 271, 313, 248, 242, 246,
#        221, 207, 235, 228, 239, 294, 253, 301, 269, 283, 278, 320, 327,
#        255, 260, 290, 297, 301, 260, 269, 271, 267, 292, 304, 304, 322,
#        340, 393, 292, 320, 327, 322, 403, 239, 258, 260, 283, 251, 235,
#        283, 255, 345, 340, 359, 366, 357, 347, 366, 373, 271, 251, 363,
#        350, 311, 212, 205, 230, 230, 357, 347, 251, 255, 239, 288, 301,
#        271, 276, 311, 276, 288, 265, 278, 260, 260, 297, 283, 251, 251,
#        239, 258, 271, 276, 276, 235, 239, 255, 246, 308, 301, 313, 311,
#        343, 338, 297, 271, 311, 294, 255, 260, 253, 242, 251, 262, 255,
#        283, 281, 265, 262, 255, 283, 281, 265, 235, 239, 269, 225, 269,
#        205, 189, 209, 202, 198, 184, 209, 202, 209, 202, 255, 253, 239,
#        242, 244, 258, 239, 242, 255, 253, 255, 253, 265, 205, 182, 209,
#        196, 313, 294, 191, 156, 251, 253, 228, 253, 255, 327, 322, 343,
#        251, 230, 223, 269, 230, 269, 253, 281, 193, 237, 202, 230, 179,
#        175, 179, 166, 129, 251, 251, 400, 283, 274, 267, 304, 338, 299,
#        306, 343, 331, 336, 334, 370, 363, 368, 386, 253, 230, 246, 225,
#        244, 228, 192, 167, 246, 225, 260, 246, 225, 244, 228, 278, 267,
#        192, 167, 239, 228, 244, 228, 192, 167, 262, 237, 285, 262, 306,
#        306, 262, 237, 285, 262, 271, 260, 267, 267, 258, 258, 235, 258,
#        253, 258, 258, 267, 258, 271, 281, 235, 267, 267, 271, 260, 258,
#        253, 288, 306], dtype=int64)

# %%
x.shape
# Out:
# (679, 9)

# %%
y.shape
# Out:
# (679,)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([("oh", OneHotEncoder(),[1,2,3,6,7])],remainder = "passthrough")
x = ct.fit_transform(x)
# Out:
# E:\Anaconda\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
x
# Out:
# <679x69 sparse matrix of type '<class 'numpy.float64'>'
# 	with 5669 stored elements in Compressed Sparse Row format>

# %%
x.shape
# Out:
# (679, 69)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2,random_state = 0)
print(x_train.shape)
print(x_test.shape)
# Out:
# (543, 69)
# (136, 69)

# %% [raw]
# from sklearn.linear_model  import LinearRegression
# lr = LinearRegression()

# %%
from sklearn.linear_model  import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_test
# Out:
# <136x69 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1140 stored elements in Compressed Sparse Row format>

# %%
y_test
# Out:
# array([292, 269, 320, 205, 304, 336, 274, 363, 248, 193, 265, 239, 386,
#        258, 363, 343, 253, 237, 373, 324, 368, 265, 265, 262, 357, 357,
#        324, 311, 267, 260, 228, 304, 396, 228, 212, 214, 294, 288, 377,
#        271, 253, 297, 317, 251, 377, 260, 313, 244, 253, 253, 253, 267,
#        251, 400, 230, 265, 265, 191, 301, 320, 253, 246, 403, 299, 212,
#        260, 322, 221, 265, 290, 260, 239, 313, 255, 357, 373, 267, 251,
#        426, 386, 338, 253, 281, 258, 253, 288, 354, 283, 285, 262, 294,
#        281, 363, 274, 260, 283, 283, 274, 391, 260, 189, 258, 205, 223,
#        288, 354, 275, 251, 301, 245, 340, 274, 255, 357, 308, 311, 225,
#        311, 182, 327, 260, 239, 391, 308, 262, 407, 258, 251, 315, 377,
#        347, 304, 260, 276, 230, 373], dtype=int64)

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([295.83547163, 272.03848646, 323.09809348, 198.66592144,
#        310.02219903, 340.05592364, 268.58547448, 355.3594723 ,
#        246.04323793, 192.4741241 , 257.29864887, 237.30225764,
#        382.9077587 , 256.99372683, 363.67867335, 337.98924066,
#        252.88173967, 238.85871773, 371.17600163, 323.60672457,
#        376.29671862, 262.82163993, 264.16760124, 260.75265916,
#        355.58234437, 357.52480135, 334.25235258, 311.19885027,
#        266.13327611, 259.07521009, 226.38367573, 312.18284308,
#        402.1270936 , 225.04239302, 211.26843281, 214.39874594,
#        293.32821692, 282.94151267, 384.69736909, 272.27459745,
#        253.54382034, 299.48913762, 322.41485045, 247.14588539,
#        381.15692905, 262.41872218, 313.08777221, 239.5541865 ,
#        255.64416803, 256.99683232, 256.88642808, 267.55622715,
#        248.3007654 , 391.70917859, 235.10288506, 257.60645391,
#        264.1997478 , 190.31675968, 304.03064461, 322.72395467,
#        253.05853281, 243.15731177, 393.49878898, 299.42358262,
#        210.64730279, 235.02475453, 324.72770813, 222.37612007,
#        263.12824715, 289.49776606, 263.21233591, 243.93186933,
#        309.43601181, 256.5223437 , 358.2758209 , 370.66328342,
#        267.09100415, 246.57453997, 427.12104094, 380.36937643,
#        315.23426161, 254.48949862, 288.21738572, 265.5358116 ,
#        252.93667357, 283.31594902, 358.05223636, 291.4541905 ,
#        283.29868129, 258.27659613, 290.67194215, 277.02934232,
#        360.5925385 , 268.2501097 , 262.23079372, 255.96552023,
#        284.56891997, 269.0338792 , 393.22271772, 266.44001106,
#        190.17849386, 258.01924464, 204.90143082, 219.58118698,
#        281.99850343, 357.52480135, 342.24854223, 251.41944428,
#        310.08264393, 309.79732698, 337.10799304, 332.2423986 ,
#        256.01413522, 355.3594723 , 305.92034692, 307.62587937,
#        224.20843327, 307.75010537, 197.14102633, 332.91635224,
#        263.28416391, 241.45319562, 390.4392993 , 307.90871261,
#        265.03989341, 394.59892426, 254.25911038, 246.76087898,
#        308.84657255, 384.38680407, 343.27780664, 303.70674761,
#        265.50973257, 277.79373607, 234.30963246, 367.56419676])

# %%
from sklearn import metrics
print("MAE:",metrics.mean_absolute_error(y_test,y_pred))
print("MSE:",metrics.mean_absolute_error(y_test,y_pred))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# MAE: 5.160838642206241
# MSE: 5.160838642206241
# RMSE: 11.000208523774937

# %%
import pickle
pickle.dump(LinearRegression,open('CO2.pkl','wb'))

# %%
pwd
# Out:
# 'E:\\Geethanjaliexternship'
